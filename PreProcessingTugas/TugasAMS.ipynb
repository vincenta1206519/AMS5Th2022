# %%
import pandas as pd
import time
import re
import string
import tweepy
import numpy as np

# %%
def twitter_config():
    """
    Fungsi utilitas untuk mengkonfigurasi konsumsi file API Twitter dengan␣
    ,!kunci yang disediakan.
    """
    # Otentikasi dan akses menggunakan kunci:
    auth = tweepy.OAuthHandler("PV6vdV2wE9psFL3nUQ5wKlyws",
    "XhwTVn0T6PJz7KBzQoRJfvUx9nzWrzy340Akfc0Hvi7SYTwKKV")
    auth.set_access_token("1286741813945016320-OwQoy7HJTRCIX8Ja75Z9FVn6KbXkHN",
    "vqpwGWaG3wFB1U5JuMvHgya2kzqnDUXFufpPGi5c8syDn")
    # Kembalikan akses ke API:
    api = tweepy.API(auth)
    try:
        api.verify_credentials()
        print("Authentication OK")
    except:
        print("Error during authentication")
    return api

# %%
extractor = twitter_config()
# Out:
# Authentication OK

# %%
tweets = extractor.user_timeline(screen_name="Telkomsel", count=100)
print("Tweets terambil: {}.\n".format(len(tweets)))


print("100 tweet teratas:\n")
for tweet in tweets[:100]:
    print(tweet.text)
    print()
# Out:
# Tweets terambil: 100.
#
# 100 tweet teratas:
#
# @FirahAlam Baik, Kak Stark. Mohon berkenan menunggu interaksi selanjutnya di DM ya Kak. Terima kasih😊-Dofi
#
# @FirahAlam Halo, Kak Stark. Maaf ya, terkait kendala aktivasi paket. Yuk infoin nomor hp dan tanggal kejadian via D… https://t.co/riSzAob0BK
#
# @t1kamer4d Dibuat gak nyaman ya, Kak George. Notifikasi tersebut merupakan promosi paket internet dari MyTelkomsel… https://t.co/2KsYB5ZW6F
#
# @andre_sni Baik, Kak Andre. Mohon berkenan menunggu interaksi selanjutnya di DM ya Kak. Terima kasih😊-Dofi
#
# @myowish Hai, Kak Alen. Telkomsel dan Disney+ Hotstar masih bekerja sama kok, jika Kakak ingin berlangganan Disney+… https://t.co/ug5OqHpHPO
#
# @Omndut0105 Hai, Kak. Maaf ya untuk ketidaksesuian tarif penawarannya. Yuk infoin nomor hp dan tanggal kejadian ke… https://t.co/tmSCQeBsB2
#
# @hesnataa Hai, Kak Hesnata. Maaf ya untuk kendala cek pulsa, yuk infoin nomor hp, tanggal kejadian dan capture kete… https://t.co/1hyKhy3Wc4
#
# ...

# %%
# Kita dapat membuat kerangka data sebagai berikut:
dataset_user = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

# Kami membuat tampilan kerangka data:
display(dataset_user.head(100))
# Out:
#                                                Tweets
# 0   @FirahAlam Baik, Kak Stark. Mohon berkenan men...
# 1   @FirahAlam Halo, Kak Stark. Maaf ya, terkait k...
# 2   @t1kamer4d Dibuat gak nyaman ya, Kak George. N...
# 3   @andre_sni Baik, Kak Andre. Mohon berkenan men...
# 4   @myowish Hai, Kak Alen. Telkomsel dan Disney+ ...
# ..                                                ...
# 95  @KaDRuN_ToL0L Aduh, Maaf ya Kak jadi gak nyama...
# 96  @kecroh Pak lurah makan kue cucur. Gea segera ...
# 97  @rutotelkomsel Makan buah sambil lembur. Mohon...
# 98  @pejuangkhilaf Hai, Kak. Maafin ya. Boleh ceri...
# 99  @pejuangkhilaf Masa sih mahal Kak? Coba kasih ...
#
# [100 rows x 1 columns]

# %%
dataset_user.to_csv('dataset_tugas.csv',sep=';')
